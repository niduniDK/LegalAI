# %%
# # Step 1: Clean installation
# !pip uninstall surya-ocr transformers torch torchvision -y

# # Step 2: Install specific compatible versions
# !pip install torch==2.1.2 torchvision==0.16.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.37.2
# !pip install surya-ocr==0.4.15

# # Step 3: Install additional dependencies
# !pip install pdf2image pillow pandas requests

# # Step 4: RESTART YOUR KERNEL (this is crucial!)
# import os, sys; os._exit(0)  # Restart after install

# %%
# !pip install torch==2.1.2 torchvision==0.16.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.37.2
# !pip install surya-ocr==0.4.15

# import importlib
# import surya
# importlib.reload(surya)

# %%
# initialize empty repo
# !git init /kaggle/working/lk_legal_docs
# %cd /kaggle/working/lk_legal_docs

# add remote and fetch only the branch
# !git remote add origin https://github.com/nuuuwan/lk_legal_docs.git
# !git fetch --depth 1 origin data

# enable sparse checkout
# !git sparse-checkout init --cone
# !git sparse-checkout set data/lk_acts

# pull only the lk_acts folder
# !git pull origin data
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /kaggle/working/lk_legal_docs/.git/
# /kaggle/working/lk_legal_docs
# remote: Enumerating objects: 270809, done.
# remote: Counting objects: 100% (270809/270809), done.
# remote: Compressing objects: 100% (94466/94466), done.
# Receiving objects: 100% (270809/270809), 7.04 GiB | 33.34 MiB/s, done.
# remote: Total 270809 (delta 86210), reused 270381 (delta 86007), pack-reused 0 (from 0)
# Resolving deltas: 100% (86210/86210), done.
# From https://github.com/nuuuwan/lk_legal_docs
#  * branch                  data       -> FETCH_HEAD
#  * [new branch]            data       -> origin/data
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 570 bytes | 285.00 KiB/s, done.
# From https://github.com/nuuuwan/lk_legal_docs
#  * branch                  data       -> FETCH_HEAD
#    8a1332faba..299c2e4950  data       -> origin/data
# Updating files: 100% (19616/19616), done.

# %%
import pandas as pd
import numpy as np

# %%
# !apt-get update -y
# !apt-get install -y poppler-utils
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:4 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [80.4 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,008 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.2 kB]
# Get:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [43.2 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,336 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,299 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,681 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,274 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,526 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [71.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,577 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,779 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Get:26 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,807 kB]
# Fetched 36.1 MB in 4s (8,945 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpoppler-dev libpoppler-private-dev libpoppler118
# The following NEW packages will be installed:
#   poppler-utils
# The following packages will be upgraded:
#   libpoppler-dev libpoppler-private-dev libpoppler118
# 3 upgraded, 1 newly installed, 0 to remove and 170 not upgraded.
# Need to get 1,471 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpoppler-private-dev amd64 22.02.0-2ubuntu0.10 [199 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpoppler-dev amd64 22.02.0-2ubuntu0.10 [5,188 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpoppler118 amd64 22.02.0-2ubuntu0.10 [1,081 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.10 [186 kB]
# Fetched 1,471 kB in 0s (11.1 MB/s)
# (Reading database ... 128663 files and directories currently installed.)
# Preparing to unpack .../libpoppler-private-dev_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking libpoppler-private-dev:amd64 (22.02.0-2ubuntu0.10) over (22.02.0-2ubuntu0.8) ...
# Preparing to unpack .../libpoppler-dev_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (22.02.0-2ubuntu0.10) over (22.02.0-2ubuntu0.8) ...
# Preparing to unpack .../libpoppler118_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking libpoppler118:amd64 (22.02.0-2ubuntu0.10) over (22.02.0-2ubuntu0.8) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.10) ...
# Setting up libpoppler118:amd64 (22.02.0-2ubuntu0.10) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.10) ...
# Setting up libpoppler-dev:amd64 (22.02.0-2ubuntu0.10) ...
# Setting up libpoppler-private-dev:amd64 (22.02.0-2ubuntu0.10) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.2 MB/s eta 0:00:00
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber) (44.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.0 MB/s eta 0:00:000:00:0100:01
# Installing collected packages: pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7

# %%
import os, json, requests, pandas as pd
from pdf2image import convert_from_bytes
from PIL import Image
import pytesseract
from tqdm import tqdm
import torch

# surya imports
from surya.model.detection.model import load_model as load_det_model
from surya.model.recognition.model import load_model as load_rec_model
from surya.model.recognition.processor import load_processor as load_rec_processor
from surya.ocr import run_ocr
from transformers import SegformerImageProcessor

DATA_DIR = "/kaggle/working/lk_legal_docs/data/lk_acts"
SAVE_PATH = "/kaggle/working/acts_si.csv"

# -------------------------------
# initialize surya models (cpu)
# -------------------------------
print("Initializing Surya OCR models (CPU)...")
device = torch.device("cpu")
det_model = load_det_model().to(device)
rec_model = load_rec_model().to(device)
rec_processor = load_rec_processor()
try:
    det_processor = SegformerImageProcessor.from_pretrained("vikp/surya_det3")
except Exception:
    det_processor = None
print("✅ Surya models ready on CPU!")

# -------------------------------
# helper functions
# -------------------------------
def download_pdf(url, timeout=30):
    try:
        resp = requests.get(url, timeout=timeout, headers={"User-Agent": "Mozilla/5.0"})
        if resp.status_code == 200:
            return resp.content
    except requests.RequestException:
        pass
    return None


def is_unicode_sinhala(text):
    """Check if text contains Sinhala unicode characters"""
    return any("\u0d80" <= ch <= "\u0dff" for ch in text)


def ocr_page(img, langs=["si"]):
    """
    OCR a single page:
    - first try pytesseract (extractable text)
    - if not usable, fallback to Surya OCR
    """
    # try pytesseract first
    try:
        text = pytesseract.image_to_string(img, lang="si")
        if is_unicode_sinhala(text) and len(text.strip()) > 5:
            return text
    except Exception:
        pass

    # fallback to Surya OCR
    preds = run_ocr([img], [langs], det_model, det_processor, rec_model, rec_processor)
    if preds and preds[0].text_lines:
        page_text = " ".join([line.text for line in preds[0].text_lines])
        return page_text
    return ""



def ocr_pdf(pdf_bytes, langs=["si"]):
    """OCR pdf page by page with tqdm progress bar"""
    images = convert_from_bytes(pdf_bytes, dpi=200)
    full_text = ""

    for i, img in enumerate(tqdm(images, desc="Processing pages", unit="page")):
        page_text = ocr_page(img, langs=langs)
        full_text += page_text + "\n\n"


    return full_text.strip()


def save_results(results, save_path):
    if not results:
        return
    df = pd.DataFrame(results)
    if not os.path.exists(save_path):
        df.to_csv(save_path, index=False, encoding="utf-8-sig")
    else:
        df.to_csv(save_path, index=False, mode="a", header=False, encoding="utf-8-sig")


# -------------------------------
# process PDFs from doc.json
# -------------------------------
def process_docjson(root_dir, save_path):
    processed = set()
    if os.path.exists(save_path):
        try:
            existing_df = pd.read_csv(save_path)
            processed.update(existing_df["name"].astype(str).tolist())
        except Exception:
            pass

    results = []
    for subdir, _, files in os.walk(root_dir):
        if "doc.json" in files:
            json_path = os.path.join(subdir, "doc.json")
            try:
                with open(json_path, "r", encoding="utf-8") as f:
                    doc = json.load(f)

                if doc.get("lang") != "si":
                    continue
                pdf_url = doc.get("url_pdf")
                if not pdf_url:
                    continue

                pdf_name = os.path.basename(pdf_url)
                if pdf_name in processed:
                    continue

                print(f"Processing {pdf_name} ...", flush=True)
                pdf_bytes = download_pdf(pdf_url)
                if pdf_bytes:
                    text = ocr_pdf(pdf_bytes, langs=["si"])
                    print(f"{pdf_name} extracted, total chars: {text[:500]}\n", flush=True)

                    results.append({
                        "name": pdf_name,
                        "url": pdf_url,
                        "text": text,
                        "character_count": len(text),
                        "status": "success" if text else "no_text"
                    })
                else:
                    results.append({
                        "name": pdf_name,
                        "url": pdf_url,
                        "text": "",
                        "character_count": 0,
                        "status": "download_failed"
                    })

                if len(results) >= 2:  # save small batches
                    save_results(results, save_path)
                    results = []
            except Exception as e:
                print(f"Error in {json_path}: {e}", flush=True)
                results.append({
                    "name": f"ERROR_{os.path.basename(json_path)}",
                    "url": "",
                    "text": "",
                    "character_count": 0,
                    "status": f"error: {str(e)[:100]}"
                })

    if results:
        save_results(results, save_path)
    print("✅ Finished! Results saved to", save_path, flush=True)


# -------------------------------
# main
# -------------------------------
if __name__ == "__main__":
    if not os.path.exists(DATA_DIR):
        print(f"❌ Data directory does not exist: {DATA_DIR}", flush=True)
    else:
        process_docjson(DATA_DIR, SAVE_PATH)
# Out:
# Initializing Surya OCR models (CPU)...
# The following layers were not sharded: decode_head.linear_c.*.proj.bias, vit.stages.*.blocks.*.main.spatial_conv.norm.running_var, vit.stages.*.blocks.*.context_module.main.proj.norm.num_batches_tracked, vit.stages.*.blocks.*.main.point_conv.norm.running_mean, vit.stages.*.blocks.*.context_module.main.proj.norm.bias, vit.stem.res*.main.conv*.conv.weight, vit.stages.*.blocks.*.main.spatial_conv.norm.running_mean, vit.stages.*.blocks.*.local_module.main.inverted_conv.conv.weight, vit.stem.res*.main.conv*.norm.running_mean, decode_head.linear_c.*.proj.weight, vit.stages.*.blocks.*.local_module.main.point_conv.norm.running_var, vit.stem.res*.main.conv*.norm.bias, decode_head.batch_norm.running_var, vit.stages.*.blocks.*.local_module.main.depth_conv.conv.weight, decode_head.classifier.bias, decode_head.batch_norm.bias, vit.stages.*.blocks.*.main.inverted_conv.conv.bias, vit.stages.*.blocks.*.local_module.main.point_conv.norm.running_mean, vit.stages.*.blocks.*.local_module.main.point_conv.conv.weight, vit.stages.*.blocks.*.context_module.main.qkv.conv.weight, vit.stages.*.blocks.*.context_module.main.aggreg.*.*.weight, vit.stages.*.blocks.*.context_module.main.proj.norm.running_var, decode_head.batch_norm.weight, vit.stages.*.blocks.*.main.point_conv.norm.running_var, vit.stages.*.blocks.*.main.spatial_conv.conv.weight, vit.stages.*.blocks.*.context_module.main.proj.norm.running_mean, vit.stages.*.blocks.*.main.point_conv.norm.num_batches_tracked, vit.stages.*.blocks.*.local_module.main.point_conv.norm.weight, decode_head.classifier.weight, vit.stages.*.blocks.*.main.point_conv.norm.bias, vit.stem.in_conv.norm.running_var, vit.stem.in_conv.norm.num_batches_tracked, decode_head.linear_fuse.weight, vit.stages.*.blocks.*.main.spatial_conv.norm.bias, vit.stem.in_conv.conv.weight, vit.stem.res*.main.conv*.norm.running_var, vit.stages.*.blocks.*.main.point_conv.conv.weight, vit.stages.*.blocks.*.local_module.main.depth_conv.conv.bias, vit.stages.*.blocks.*.main.inverted_conv.conv.weight, vit.stages.*.blocks.*.local_module.main.point_conv.norm.bias, vit.stages.*.blocks.*.context_module.main.proj.norm.weight, decode_head.batch_norm.running_mean, vit.stages.*.blocks.*.main.spatial_conv.norm.weight, vit.stages.*.blocks.*.main.point_conv.norm.weight, vit.stem.in_conv.norm.weight, vit.stages.*.blocks.*.local_module.main.point_conv.norm.num_batches_tracked, vit.stages.*.blocks.*.main.depth_conv.conv.weight, vit.stages.*.blocks.*.main.spatial_conv.norm.num_batches_tracked, vit.stages.*.blocks.*.context_module.main.proj.conv.weight, vit.stages.*.blocks.*.main.depth_conv.conv.bias, vit.stages.*.blocks.*.local_module.main.inverted_conv.conv.bias, vit.stem.in_conv.norm.bias, vit.stem.in_conv.norm.running_mean, decode_head.batch_norm.num_batches_tracked, vit.stem.res*.main.conv*.norm.weight, vit.stem.res*.main.conv*.norm.num_batches_tracked
# Loaded detection model vikp/surya_det3 on device cpu with dtype torch.float32
# Loaded recognition model vikp/surya_rec on device cpu with dtype torch.float32
# ✅ Surya models ready on CPU!
# Processing 05-2024_S.pdf ...
# /usr/local/lib/python3.11/dist-packages/transformers/image_processing_base.py:417: UserWarning: The following named arguments are not valid for `SegformerImageProcessor.__init__` and were ignored: '_valid_processor_keys'
#   image_processor = cls(**image_processor_dict)
# Processing pages:   0%|          | 0/13 [00:00<?, ?page/s]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.70s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:31<00:00, 31.82s/it]
# Processing pages:   8%|▊         | 1/13 [00:41<08:22, 41.91s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.66s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:00<01:00, 60.21s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:11<00:00, 35.78s/it]
# Processing pages:  15%|█▌        | 2/13 [02:03<12:00, 65.46s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.05s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:57<00:57, 57.74s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:15<00:00, 37.62s/it]
# Processing pages:  23%|██▎       | 3/13 [03:28<12:23, 74.39s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.28s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:56<00:56, 56.84s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:20<00:00, 40.10s/it]
# Processing pages:  31%|███       | 4/13 [04:59<12:05, 80.66s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.10s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.91s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:22<00:00, 41.07s/it]
# Processing pages:  38%|███▊      | 5/13 [06:31<11:18, 84.75s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.21s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:56<00:56, 56.70s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:11<00:00, 35.50s/it]
# Processing pages:  46%|████▌     | 6/13 [07:52<09:44, 83.45s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.10s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:57<00:57, 57.22s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:24<00:00, 42.40s/it]
# Processing pages:  54%|█████▍    | 7/13 [09:26<08:42, 87.14s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.10s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:57<00:57, 57.85s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:12<00:00, 36.19s/it]
# Processing pages:  62%|██████▏   | 8/13 [10:48<07:07, 85.57s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.44s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:20<01:20, 80.86s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:31<00:00, 45.61s/it]
# Processing pages:  69%|██████▉   | 9/13 [12:30<06:01, 90.50s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.12s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.69s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:17<00:00, 38.85s/it]
# Processing pages:  77%|███████▋  | 10/13 [13:57<04:28, 89.61s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.35s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:58<00:58, 58.82s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:00<00:00, 30.30s/it]
# Processing pages:  85%|████████▍ | 11/13 [15:08<02:47, 83.77s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.35s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:27<00:00, 27.16s/it]
# Processing pages:  92%|█████████▏| 12/13 [15:45<01:09, 69.50s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.20s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:07<00:00,  7.62s/it]
# Processing pages: 100%|██████████| 13/13 [16:02<00:00, 74.03s/page]
# 05-2024_S.pdf extracted, total chars: ශ්‍රී ලංකා ප්‍රජාතාන්ත්‍රික සමාජවාදී ජනරජයේ පාර්ලිමේන්තුව 2024 අංක 5 දරන සමථකරණය තුළින් ඇතිවන්නා වූ අන්තර්ජාතික නිරවුල්කරණ ගිවිසුම් පිළිගැනීමේ සහ බලාත්මක කිරීමේ පනත [සහතිකය සටහන් කළේ 2024 ජනවාරි මස 31 වන දින] ආණ්ඩුවේ නියමය පරිදි මුද්‍රණය කරන ලදී 2024 පෙබරවාරි මස 02 වන දින ශ්‍රී ලංකා ප්‍රජාතාන්ත්‍රික සමාජවාදී ජනරජයේ ගැසට් පත්‍රයේ II වන කොටසේ අතිරේකයක් වශයෙන් පළ කරන ලදී  ශ්‍රී ලංකා රජයේ මුද්‍රණ දෙපාර්තමේන්තුවේ මුද්‍රණය කරන ලදී.  කොළඹ 5, රජයේ ප්‍රකාශන කාර්යාංශයෙන් මිලදී ලබාගත හැකි ය. මිල : රු. 24.0
#
# Processing 02-2024_S.pdf ...
# Processing pages:   0%|          | 0/13 [00:00<?, ?page/s]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.06s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:25<00:00, 25.26s/it]
# Processing pages:   8%|▊         | 1/13 [00:34<06:55, 34.66s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.12s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:58<00:58, 58.56s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:12<00:00, 36.32s/it]
# Processing pages:  15%|█▌        | 2/13 [01:57<11:30, 62.78s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.07s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:55<00:55, 55.40s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:04<00:00, 32.11s/it]
# Processing pages:  23%|██▎       | 3/13 [03:11<11:18, 67.88s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.26s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:55<00:55, 55.95s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:00<00:00, 30.40s/it]
# Processing pages:  31%|███       | 4/13 [04:21<10:20, 68.99s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.34s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:54<00:54, 54.57s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:09<00:00, 34.73s/it]
# Processing pages:  38%|███▊      | 5/13 [05:41<09:42, 72.78s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.16s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:56<00:56, 56.84s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:22<00:00, 41.02s/it]
# Processing pages:  46%|████▌     | 6/13 [07:13<09:15, 79.32s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.17s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:57<00:57, 57.49s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:09<00:00, 34.93s/it]
# Processing pages:  54%|█████▍    | 7/13 [08:32<07:56, 79.45s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.60s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.02s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:34<00:00, 47.00s/it]
# Processing pages:  62%|██████▏   | 8/13 [10:17<07:17, 87.41s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.90s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:27<01:27, 87.12s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:40<00:00, 50.07s/it]
# Processing pages:  69%|██████▉   | 9/13 [12:08<06:18, 94.71s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.65s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.26s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:21<00:00, 40.99s/it]
# Processing pages:  77%|███████▋  | 10/13 [13:40<04:42, 94.00s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.21s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:57<00:57, 57.50s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:03<00:00, 31.94s/it]
# Processing pages:  85%|████████▍ | 11/13 [14:55<02:56, 88.12s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.11s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:59<00:00, 59.95s/it]
# Processing pages:  92%|█████████▏| 12/13 [16:06<01:22, 82.80s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.54s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:07<00:00,  7.79s/it]
# Processing pages: 100%|██████████| 13/13 [16:24<00:00, 75.73s/page]
# 02-2024_S.pdf extracted, total chars: ශ්‍රී ලංකා ප්‍රජාතාන්ත්‍රික සමාජවාදී ජනරජයේ පාර්ලිමේන්තුව 2024 අංක 2 දරන සමථ මණ්ඩල (සංශෝධන) පනත [සහතිකය සටහන් කළේ 2024 ජනවාරි මස 23 වන දින] ආණ්ඩුවේ නියමය පරිදි මුද්‍රණය කරන ලදී 2024 ජනවාරි මස 26 වන දින ශ්‍රී ලංකා ප්‍රජාතාන්ත්‍රික සමාජවාදී ජනරජයේ ගැසට් පත්‍රයේ II වන කොටසේ අතිරේකයක් වශයෙන් පළ කරන ලදී  ශ්‍රී ලංකා රජයේ මුද්‍රණ දෙපාර්තමේන්තුවේ මුද්‍රණය කරන ලදී.  කොළඹ 5, රජයේ ප්‍රකාශන කාර්යාංශයෙන් මිලදී ලබාගත හැකි ය. මිල : රු. 24.00 තැපැල් ගාස්තුව : රු. 150.00  මෙම පනත www.documents.gov.lk වෙබ් අඩවියෙ
#
# Processing 17-2024_S.pdf ...
# Processing pages:   0%|          | 0/71 [00:00<?, ?page/s]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:12<00:00, 12.61s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:29<00:00, 29.44s/it]
# Processing pages:   1%|▏         | 1/71 [00:42<49:28, 42.41s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.20s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.79s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:24<00:00, 42.38s/it]
# Processing pages:   4%|▍         | 3/71 [03:53<1:35:09, 83.96s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.59s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:58<00:58, 58.90s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:20<00:00, 40.11s/it]
# Processing pages:   6%|▌         | 4/71 [05:25<1:37:06, 86.96s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.79s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.85s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:12<00:00, 36.15s/it]
# Processing pages:   7%|▋         | 5/71 [06:49<1:34:22, 85.80s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.72s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:08<01:08, 68.27s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:33<00:00, 46.81s/it]
# Processing pages:   8%|▊         | 6/71 [08:34<1:40:04, 92.37s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.29s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:29<01:29, 89.73s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:52<00:00, 56.44s/it]
# Processing pages:  10%|▉         | 7/71 [10:37<1:49:29, 102.66s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.91s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:32<01:32, 92.01s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:52<00:00, 56.41s/it]
# Processing pages:  11%|█▏        | 8/71 [12:42<1:55:04, 109.60s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.10s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.58s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:27<00:00, 43.59s/it]
# Processing pages:  13%|█▎        | 9/71 [14:21<1:49:51, 106.31s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.41s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:03<01:03, 63.02s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:14<00:00, 37.42s/it]
# Processing pages:  14%|█▍        | 10/71 [15:48<1:41:59, 100.32s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.49s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:05<01:05, 65.24s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:28<00:00, 44.11s/it]
# Processing pages:  17%|█▋        | 12/71 [19:01<1:36:59, 98.63s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:28<00:00, 28.85s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:04<01:04, 64.47s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:17<00:00, 38.99s/it]
# Processing pages:  18%|█▊        | 13/71 [20:48<1:37:58, 101.35s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.91s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.47s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:24<00:00, 42.40s/it]
# Processing pages:  20%|█▉        | 14/71 [22:25<1:34:52, 99.87s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.68s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.72s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:30<00:00, 45.44s/it]
# Processing pages:  21%|██        | 15/71 [24:07<1:33:54, 100.62s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.42s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.28s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:10<00:00, 35.09s/it]
# Processing pages:  23%|██▎       | 16/71 [25:29<1:27:09, 95.09s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.41s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.39s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:39<00:00, 49.87s/it]
# Processing pages:  24%|██▍       | 17/71 [27:21<1:30:10, 100.19s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.27s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.73s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:22<00:00, 41.16s/it]
# Processing pages:  25%|██▌       | 18/71 [28:56<1:26:56, 98.43s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.34s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:21<01:21, 81.80s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:44<00:00, 52.12s/it]
# Processing pages:  27%|██▋       | 19/71 [30:52<1:29:57, 103.80s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.62s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:03<01:03, 63.91s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:10<00:00, 35.29s/it]
# Processing pages:  28%|██▊       | 20/71 [32:15<1:22:52, 97.50s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.06s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:03<01:03, 63.74s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:10<00:00, 35.36s/it]
# Processing pages:  30%|██▉       | 21/71 [33:37<1:17:28, 92.96s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.18s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.22s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:18<00:00, 39.27s/it]
# Processing pages:  31%|███       | 22/71 [35:08<1:15:18, 92.20s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.60s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.89s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:22<00:00, 41.33s/it]
# Processing pages:  32%|███▏      | 23/71 [36:43<1:14:25, 93.04s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.04s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [01:27<00:00, 87.25s/it]
# Processing pages:  34%|███▍      | 24/71 [38:21<1:14:15, 94.79s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.96s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.11s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:15<00:00, 37.51s/it]
# Processing pages:  35%|███▌      | 25/71 [39:48<1:10:48, 92.35s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:11<00:00, 11.68s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:26<01:26, 86.74s/it]
# Recognizing Text: 100%|██████████| 2/2 [02:00<00:00, 60.01s/it]
# Processing pages:  37%|███▋      | 26/71 [42:01<1:18:21, 104.47s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.69s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [01:29<00:00, 89.25s/it]
# Processing pages:  38%|███▊      | 27/71 [43:40<1:15:31, 102.99s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.87s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:00<01:00, 60.58s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:16<00:00, 38.03s/it]
# Processing pages:  39%|███▉      | 28/71 [45:07<1:10:17, 98.09s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.10s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.67s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:06<00:00, 33.26s/it]
# Processing pages:  41%|████      | 29/71 [46:24<1:04:17, 91.85s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.95s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [01:28<00:00, 88.09s/it]
# Processing pages:  42%|████▏     | 30/71 [48:03<1:04:09, 93.88s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.78s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:29<01:29, 89.93s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:48<00:00, 54.43s/it]
# Processing pages:  44%|████▎     | 31/71 [50:02<1:07:41, 101.53s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.14s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:49<01:49, 109.76s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:56<00:00, 58.28s/it]
# Processing pages:  45%|████▌     | 32/71 [52:10<1:11:01, 109.28s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.82s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:28<01:28, 88.24s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:43<00:00, 51.54s/it]
# Processing pages:  46%|████▋     | 33/71 [54:03<1:10:02, 110.58s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.96s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:59<00:00, 59.74s/it]
# Processing pages:  48%|████▊     | 34/71 [55:14<1:00:44, 98.49s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:09<00:00,  9.73s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:28<01:28, 88.32s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:45<00:00, 52.71s/it]
# Processing pages:  49%|████▉     | 35/71 [57:09<1:02:13, 103.70s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.50s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:03<01:03, 63.47s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:21<00:00, 40.90s/it]
# Processing pages:  51%|█████     | 36/71 [58:43<58:40, 100.58s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.22s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:29<01:29, 89.97s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:40<00:00, 50.20s/it]
# Processing pages:  52%|█████▏    | 37/71 [1:00:34<58:48, 103.79s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.35s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.22s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:11<00:00, 35.75s/it]
# Processing pages:  54%|█████▎    | 38/71 [1:01:56<53:34, 97.41s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.28s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.47s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:11<00:00, 35.54s/it]
# Processing pages:  55%|█████▍    | 39/71 [1:03:19<49:29, 92.80s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.33s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [00:59<00:59, 59.59s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:08<00:00, 34.46s/it]
# Processing pages:  56%|█████▋    | 40/71 [1:04:38<45:56, 88.93s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.02s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.63s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:11<00:00, 35.60s/it]
# Processing pages:  58%|█████▊    | 41/71 [1:06:00<43:24, 86.81s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.02s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.24s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:10<00:00, 35.02s/it]
# Processing pages:  59%|█████▉    | 42/71 [1:07:21<41:04, 84.99s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.30s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.65s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:33<00:00, 46.91s/it]
# Processing pages:  61%|██████    | 43/71 [1:09:06<42:27, 90.99s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.19s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:04<01:04, 64.86s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:52<00:00, 56.18s/it]
# Processing pages:  62%|██████▏   | 44/71 [1:11:09<45:19, 100.72s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.23s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:28<01:28, 88.02s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:49<00:00, 54.69s/it]
# Processing pages:  63%|██████▎   | 45/71 [1:13:10<46:12, 106.62s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.22s/it]
#
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
# Recognizing Text: 100%|██████████| 1/1 [01:00<00:00, 60.81s/it]
# Processing pages:  65%|██████▍   | 46/71 [1:14:21<40:03, 96.13s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.40s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.55s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:28<00:00, 44.45s/it]
# Processing pages:  66%|██████▌   | 47/71 [1:16:02<38:55, 97.32s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.43s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:00<01:00, 60.45s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:21<00:00, 40.77s/it]
# Processing pages:  68%|██████▊   | 48/71 [1:17:34<36:46, 95.96s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.36s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.45s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:54<00:00, 57.01s/it]
# Processing pages:  69%|██████▉   | 49/71 [1:19:40<38:24, 104.74s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.27s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:01<01:01, 61.13s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:38<00:00, 49.16s/it]
# Processing pages:  70%|███████   | 50/71 [1:21:29<37:09, 106.19s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.31s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
# Recognizing Text:  50%|█████     | 1/2 [01:02<01:02, 62.30s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:21<00:00, 40.84s/it]
# Processing pages:  72%|███████▏  | 51/71 [1:23:02<34:03, 102.16s/page]
# Detecting bboxes:   0%|          | 0/1 [00:00<?, ?it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:10<00:00, 10.42s/it]
#
# Recognizing Text:   0%|          | 0/2 [00:00<?, ?it/s]
